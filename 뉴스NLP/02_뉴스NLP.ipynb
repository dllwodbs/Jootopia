# %%
from pykrx import stock
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_excel('삼성전자2025.xlsx')

# %%
def normalize(text):
    # 특수문자 제외, 공백에 대한 처리
    text = re.sub(r"[^가-힣0-9a-zA-Z\s\.]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# 금융 문장 감성 분석 모델
MODEL = "snunlp/KR-FinBert-SC"

# 1) 토크나이저/모델 로드
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# 2) 파이프라인 생성
nlp = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    return_all_scores=True
)

# 테스트
sentence = "삼성전자는 반도체 업황 개선으로 실적이 대폭 증가했다."
result = nlp(sentence)

print(result)
# Out:
# Device set to use cpu
# [[{'label': 'negative', 'score': 5.399243309511803e-05}, {'label': 'neutral', 'score': 6.116756412666291e-05}, {'label': 'positive', 'score': 0.999884843826294}]]
# c:\Users\rkdtk\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py:111: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
df['제목'] = df['제목'].map(normalize)

# %%
df = df[['일자', '제목']]
df.rename(columns={'일자':'date', '제목':'title'}, inplace=True)

# %%
df
# Out:
#            date                                 title
# 0      20251203   2025년 TTA 시험인증 대상 특별상 삼성전자 갤럭시S25FE
# 1      20251203               삼성전자 GDDR7 D램으로 대통령상 수상
# 2      20251203   삼성전자 삼성 아트 스토어 아트 바젤 마이애미 비치 컬렉션 공개
# 3      20251203   포토 TTA 시험인증 대상 특별상에 삼성전자 갤럭시 S25 FE
# 4      20251203       삼성전자 베트남 국적 임원 첫 탄생 현지 진출 17년 만
# ...         ...                                   ...
# 16239  20250101        삼성전자 레인보우로보틱스 품었다 미래 로봇 개발 가속도
# 16240  20250101           로봇기업 품은 삼성전자 대표가 직접 지휘봉 잡는다
# 16241  20250101         빅테크 새 격전지는 로봇 삼성전자도 휴머노이드 만든다
# 16242  20250101  삼성전자 AI RAN기술 시연 통신 AI 융합기술로 미래 준비한다
# 16243  20250101  삼성전자 레인보우로보틱스 최대주주 지위 확보 미래로봇 개발 가속화
#
# [16244 rows x 2 columns]

# %%
df2 = df.copy()

# %%
df2 = df[:100]

# %%
df2
# Out:
#         date                                        title
# 0   20251203          2025년 TTA 시험인증 대상 특별상 삼성전자 갤럭시S25FE
# 1   20251203                      삼성전자 GDDR7 D램으로 대통령상 수상
# 2   20251203          삼성전자 삼성 아트 스토어 아트 바젤 마이애미 비치 컬렉션 공개
# 3   20251203          포토 TTA 시험인증 대상 특별상에 삼성전자 갤럭시 S25 FE
# 4   20251203              삼성전자 베트남 국적 임원 첫 탄생 현지 진출 17년 만
# ..       ...                                          ...
# 95  20251202  삼성전자 첫 3단 폴더블폰 갤럭시 Z 트라이폴드 데뷔 힌지 대화면 완성도 개선
# 96  20251202          주머니 속 태블릿 현실로 삼성전자 Z 트라이폴드 로 초격차 승부
# 97  20251202            삼성전자 대화면 갤럭시 Z 트라이폴드 공개 출고가 359만원
# 98  20251202          삼성전자 첫 3단 폴더블 갤럭시 Z 트라이폴드 공개 359만 원
# 99  20251202               삼성전자 폐알루미늄 재활용 SSD T7 리저렉티드 출시
#
# [100 rows x 2 columns]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import pandas as pd
from tqdm import tqdm

# 1) 모델 로드
MODEL = "snunlp/KR-FinBert-SC"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

nlp = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    return_all_scores=True
)


# 2) 제목 감성 점수 산출 함수
def get_sentiment(title: str) -> float:
    if not isinstance(title, str):
        return 0.0
    scores = nlp(title)[0]  # [{label, score}, {label, score}, ...]
    pos = [s['score'] for s in scores if s['label'] == 'positive'][0]
    neg = [s['score'] for s in scores if s['label'] == 'negative'][0]
    return pos - neg


# 4) 감성 점수 생성
tqdm.pandas(desc="Scoring titles")
df2["sentiment"] = df2["title"].progress_apply(get_sentiment)

# 5) 종목/일자별 평균 팩터 생성
# factor = (
#     df.groupby(["date", "ticker"])["sentiment"]
#     .mean()
#     .reset_index()
# )

# factor.to_csv("sentiment_factor.csv", index=False)
# print("저장 완료 → sentiment_factor.csv")

df
# Out:
# Device set to use cpu
# c:\Users\rkdtk\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py:111: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Scoring titles: 100%|██████████| 100/100 [00:03<00:00, 30.29it/s]
# C:\Users\rkdtk\AppData\Local\Temp\ipykernel_33568\1761116401.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sentiment"] = df2["title"].progress_apply(get_sentiment)
#            date                                 title
# 0      20251203   2025년 TTA 시험인증 대상 특별상 삼성전자 갤럭시S25FE
# 1      20251203               삼성전자 GDDR7 D램으로 대통령상 수상
# 2      20251203   삼성전자 삼성 아트 스토어 아트 바젤 마이애미 비치 컬렉션 공개
# 3      20251203   포토 TTA 시험인증 대상 특별상에 삼성전자 갤럭시 S25 FE
# 4      20251203       삼성전자 베트남 국적 임원 첫 탄생 현지 진출 17년 만
# ...         ...                                   ...
# 16239  20250101        삼성전자 레인보우로보틱스 품었다 미래 로봇 개발 가속도
# 16240  20250101           로봇기업 품은 삼성전자 대표가 직접 지휘봉 잡는다
# 16241  20250101         빅테크 새 격전지는 로봇 삼성전자도 휴머노이드 만든다
# 16242  20250101  삼성전자 AI RAN기술 시연 통신 AI 융합기술로 미래 준비한다
# 16243  20250101  삼성전자 레인보우로보틱스 최대주주 지위 확보 미래로봇 개발 가속화
#
# [16244 rows x 2 columns]

# %%
df2
# Out:
#         date                                        title  sentiment
# 0   20251203          2025년 TTA 시험인증 대상 특별상 삼성전자 갤럭시S25FE   0.999440
# 1   20251203                      삼성전자 GDDR7 D램으로 대통령상 수상   0.999800
# 2   20251203          삼성전자 삼성 아트 스토어 아트 바젤 마이애미 비치 컬렉션 공개   0.999762
# 3   20251203          포토 TTA 시험인증 대상 특별상에 삼성전자 갤럭시 S25 FE   0.044790
# 4   20251203              삼성전자 베트남 국적 임원 첫 탄생 현지 진출 17년 만   0.999831
# ..       ...                                          ...        ...
# 95  20251202  삼성전자 첫 3단 폴더블폰 갤럭시 Z 트라이폴드 데뷔 힌지 대화면 완성도 개선   0.999823
# 96  20251202          주머니 속 태블릿 현실로 삼성전자 Z 트라이폴드 로 초격차 승부   0.004698
# 97  20251202            삼성전자 대화면 갤럭시 Z 트라이폴드 공개 출고가 359만원   0.999694
# 98  20251202          삼성전자 첫 3단 폴더블 갤럭시 Z 트라이폴드 공개 359만 원   0.999825
# 99  20251202               삼성전자 폐알루미늄 재활용 SSD T7 리저렉티드 출시   0.999826
#
# [100 rows x 3 columns]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# 금융 문장 감성 분석 모델
MODEL = "snunlp/KR-FinBert-SC"

# 1) 토크나이저/모델 로드
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# 2) 파이프라인 생성
nlp = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer
    # return_all_scores=True
)

# 테스트
sentence = "삼성전자는 반도체 업황 개선으로 실적이 대폭 증가했다."
result = nlp(sentence)

print(result)
# Out:
# Device set to use cpu
# [{'label': 'positive', 'score': 0.999884843826294}]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# 금융 문장 감성 분석 모델
MODEL = "snunlp/KR-FinBert-SC"

# 1) 토크나이저/모델 로드
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# 2) 파이프라인 생성
nlp = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer
    # return_all_scores=True
)

result = []
# 테스트
sentence = df['title']
for title in df['title']:
    result.append(nlp(title))
    if len(result) % 1000 == 0:
        print(f"Processed {len(result)} titles")


result
# Out:
# Device set to use cpu
# Processed 1000 titles
# Processed 2000 titles
# Processed 3000 titles
# Processed 4000 titles
# Processed 5000 titles
# Processed 6000 titles
# Processed 7000 titles
# Processed 8000 titles
# Processed 9000 titles
# Processed 10000 titles
# Processed 11000 titles
# Processed 12000 titles
# Processed 13000 titles
# Processed 14000 titles
# Processed 15000 titles
# Processed 16000 titles
# [[{'label': 'positive', 'score': 0.9995007514953613}],
#  [{'label': 'positive', 'score': 0.9998449087142944}],
#  [{'label': 'positive', 'score': 0.999800980091095}],
#  [{'label': 'neutral', 'score': 0.9485037326812744}],
#  [{'label': 'positive', 'score': 0.9998810291290283}],
#  [{'label': 'neutral', 'score': 0.8645607233047485}],
#  [{'label': 'positive', 'score': 0.9997842907905579}],
#  [{'label': 'positive', 'score': 0.9996848106384277}],
#  [{'label': 'positive', 'score': 0.9998683929443359}],
#  [{'label': 'neutral', 'score': 0.9998403787612915}],
#  [{'label': 'positive', 'score': 0.9998750686645508}],
#  [{'label': 'neutral', 'score': 0.9977598190307617}],
#  [{'label': 'positive', 'score': 0.9995802044868469}],
#  [{'label': 'neutral', 'score': 0.9875701069831848}],
#  [{'label': 'positive', 'score': 0.9998804330825806}],
#  [{'label': 'neutral', 'score': 0.9866625666618347}],
#  [{'label': 'neutral', 'score': 0.871303915977478}],
#  [{'label': 'positive', 'score': 0.9738455414772034}],
#  [{'label': 'positive', 'score': 0.9988375306129456}],
#  [{'label': 'positive', 'score': 0.9998793601989746}],
#  [{'label': 'positive', 'score': 0.9994471669197083}],
#  [{'label': 'positive', 'score': 0.9797781705856323}],
#  [{'label': 'positive', 'score': 0.9998520612716675}],
#  [{'label': 'neutral', 'score': 0.9937732815742493}],
#  [{'label': 'positive', 'score': 0.9998672008514404}],
#  [{'label': 'positive', 'score': 0.9971267580986023}],
#  [{'label': 'positive', 'score': 0.9998605251312256}],
#  [{'label': 'positive', 'score': 0.9998630285263062}],
#  [{'label': 'positive', 'score': 0.9995986819267273}],
#  [{'label': 'neutral', 'score': 0.9995242357254028}],
#  [{'label': 'neutral', 'score': 0.9904727339744568}],
#  [{'label': 'positive', 'score': 0.9998766183853149}],
#  [{'label': 'positive', 'score': 0.9997068047523499}],
#  [{'label': 'neutral', 'score': 0.9998910427093506}],
#  [{'label': 'positive', 'score': 0.999817430973053}],
#  [{'label': 'positive', 'score': 0.9998220801353455}],
#  [{'label': 'positive', 'score': 0.9998728036880493}],
#  [{'label': 'neutral', 'score': 0.9903048276901245}],
#  [{'label': 'neutral', 'score': 0.9382712244987488}],
#  [{'label': 'neutral', 'score': 0.9855905771255493}],
#  [{'label': 'neutral', 'score': 0.8569716811180115}],
#  [{'label': 'neutral', 'score': 0.9982395172119141}],
#  [{'label': 'neutral', 'score': 0.9998225569725037}],
#  [{'label': 'neutral', 'score': 0.9998663663864136}],
#  [{'label': 'neutral', 'score': 0.8165839910507202}],
#  [{'label': 'neutral', 'score': 0.9998527765274048}],
#  [{'label': 'positive', 'score': 0.9988272786140442}],
#  [{'label': 'neutral', 'score': 0.9992955923080444}],
#  [{'label': 'positive', 'score': 0.9998699426651001}],
#  [{'label': 'neutral', 'score': 0.9995545744895935}],
#  [{'label': 'positive', 'score': 0.9938018918037415}],
#  [{'label': 'positive', 'score': 0.9998568296432495}],
#  [{'label': 'positive', 'score': 0.9998689889907837}],
#  [{'label': 'neutral', 'score': 0.9997969269752502}],
#  [{'label': 'neutral', 'score': 0.999729335308075}],
#  [{'label': 'neutral', 'score': 0.9989221096038818}],
#  [{'label': 'neutral', 'score': 0.9997125267982483}],
#  [{'label': 'neutral', 'score': 0.9998117089271545}],
#  [{'label': 'neutral', 'score': 0.9998539686203003}],
#  [{'label': 'positive', 'score': 0.9983079433441162}],
#  [{'label': 'neutral', 'score': 0.9904667735099792}],
#  [{'label': 'positive', 'score': 0.9998561143875122}],
#  [{'label': 'neutral', 'score': 0.9998075366020203}],
#  [{'label': 'positive', 'score': 0.998752236366272}],
#  [{'label': 'positive', 'score': 0.999854564666748}],
#  [{'label': 'positive', 'score': 0.9835800528526306}],
#  [{'label': 'neutral', 'score': 0.99982088804245}],
#  [{'label': 'positive', 'score': 0.9992427825927734}],
#  [{'label': 'positive', 'score': 0.9998677968978882}],
#  [{'label': 'positive', 'score': 0.9982632994651794}],
#  [{'label': 'positive', 'score': 0.9998123049736023}],
#  [{'label': 'positive', 'score': 0.9996750354766846}],
#  [{'label': 'positive', 'score': 0.999864935874939}],
#  [{'label': 'positive', 'score': 0.999858021736145}],
#  [{'label': 'positive', 'score': 0.9995692372322083}],
#  [{'label': 'positive', 'score': 0.9992660880088806}],
#  [{'label': 'positive', 'score': 0.9997853636741638}],
#  [{'label': 'positive', 'score': 0.9996945858001709}],
#  [{'label': 'positive', 'score': 0.999874472618103}],
#  [{'label': 'positive', 'score': 0.999869704246521}],
#  [{'label': 'neutral', 'score': 0.8871569037437439}],
#  [{'label': 'positive', 'score': 0.9997982382774353}],
#  [{'label': 'neutral', 'score': 0.9996159076690674}],
#  [{'label': 'positive', 'score': 0.999869704246521}],
#  [{'label': 'positive', 'score': 0.9998620748519897}],
#  [{'label': 'positive', 'score': 0.9992725253105164}],
#  [{'label': 'positive', 'score': 0.9998689889907837}],
#  [{'label': 'positive', 'score': 0.9998610019683838}],
#  [{'label': 'positive', 'score': 0.9998610019683838}],
#  [{'label': 'positive', 'score': 0.999859094619751}],
#  [{'label': 'positive', 'score': 0.9998660087585449}],
#  [{'label': 'positive', 'score': 0.9998703002929688}],
#  [{'label': 'positive', 'score': 0.999862790107727}],
#  [{'label': 'positive', 'score': 0.9990839958190918}],
#  [{'label': 'positive', 'score': 0.9971877932548523}],
#  [{'label': 'positive', 'score': 0.9998600482940674}],
#  [{'label': 'neutral', 'score': 0.9577122330665588}],
#  [{'label': 'positive', 'score': 0.9997957348823547}],
#  [{'label': 'positive', 'score': 0.999862790107727}],
#  [{'label': 'positive', 'score': 0.9998595714569092}],
#  [{'label': 'positive', 'score': 0.9998412132263184}],
#  [{'label': 'positive', 'score': 0.9998679161071777}],
#  [{'label': 'positive', 'score': 0.999562680721283}],
#  [{'label': 'neutral', 'score': 0.9926624298095703}],
#  [{'label': 'neutral', 'score': 0.9996095299720764}],
#  [{'label': 'positive', 'score': 0.9998441934585571}],
#  [{'label': 'neutral', 'score': 0.999895453453064}],
#  [{'label': 'positive', 'score': 0.9998301267623901}],
#  [{'label': 'negative', 'score': 0.6551170349121094}],
#  [{'label': 'negative', 'score': 0.9992648959159851}],
#  [{'label': 'negative', 'score': 0.9984856247901917}],
#  [{'label': 'negative', 'score': 0.9995720982551575}],
#  [{'label': 'negative', 'score': 0.7808825969696045}],
#  [{'label': 'positive', 'score': 0.9998632669448853}],
#  [{'label': 'neutral', 'score': 0.9987066984176636}],
#  [{'label': 'neutral', 'score': 0.9818764925003052}],
#  [{'label': 'neutral', 'score': 0.8862680792808533}],
#  [{'label': 'positive', 'score': 0.9998667240142822}],
#  [{'label': 'positive', 'score': 0.9998713731765747}],
#  [{'label': 'positive', 'score': 0.9998469352722168}],
#  [{'label': 'positive', 'score': 0.9998646974563599}],
#  [{'label': 'positive', 'score': 0.9998687505722046}],
#  [{'label': 'positive', 'score': 0.9998607635498047}],
#  [{'label': 'positive', 'score': 0.9998698234558105}],
#  [{'label': 'positive', 'score': 0.9998217225074768}],
#  [{'label': 'positive', 'score': 0.9998750686645508}],
#  [{'label': 'neutral', 'score': 0.9987854361534119}],
#  [{'label': 'positive', 'score': 0.9998853206634521}],
#  [{'label': 'positive', 'score': 0.9998660087585449}],
#  [{'label': 'neutral', 'score': 0.9952556490898132}],
#  [{'label': 'positive', 'score': 0.9998650550842285}],
#  [{'label': 'positive', 'score': 0.7026015520095825}],
#  [{'label': 'positive', 'score': 0.999876856803894}],
#  [{'label': 'positive', 'score': 0.999863862991333}],
#  [{'label': 'positive', 'score': 0.9998847246170044}],
#  [{'label': 'negative', 'score': 0.9316537976264954}],
#  [{'label': 'positive', 'score': 0.9814712405204773}],
#  [{'label': 'positive', 'score': 0.9998733997344971}],
#  [{'label': 'positive', 'score': 0.9998655319213867}],
#  [{'label': 'neutral', 'score': 0.9998134970664978}],
#  [{'label': 'neutral', 'score': 0.9997130036354065}],
#  [{'label': 'neutral', 'score': 0.9998134970664978}],
#  [{'label': 'neutral', 'score': 0.7764983773231506}],
#  [{'label': 'neutral', 'score': 0.9913138747215271}],
#  [{'label': 'neutral', 'score': 0.9964436888694763}],
#  [{'label': 'neutral', 'score': 0.999437153339386}],
#  [{'label': 'neutral', 'score': 0.9978420734405518}],
#  [{'label': 'neutral', 'score': 0.9998979568481445}],
#  [{'label': 'neutral', 'score': 0.999247670173645}],
#  [{'label': 'neutral', 'score': 0.969950258731842}],
#  [{'label': 'positive', 'score': 0.9402002692222595}],
#  [{'label': 'positive', 'score': 0.9998711347579956}],
#  [{'label': 'positive', 'score': 0.9995555281639099}],
#  [{'label': 'negative', 'score': 0.9996540546417236}],
#  [{'label': 'positive', 'score': 0.9998750686645508}],
#  [{'label': 'positive', 'score': 0.9998722076416016}],
#  [{'label': 'positive', 'score': 0.9987909197807312}],
#  [{'label': 'positive', 'score': 0.9985211491584778}],
#  [{'label': 'positive', 'score': 0.9997753500938416}],
#  [{'label': 'positive', 'score': 0.9997615218162537}],
#  [{'label': 'positive', 'score': 0.967714250087738}],
#  [{'label': 'neutral', 'score': 0.834823489189148}],
#  [{'label': 'neutral', 'score': 0.9595633149147034}],
#  [{'label': 'positive', 'score': 0.9898118376731873}],
#  [{'label': 'neutral', 'score': 0.6991019248962402}],
#  [{'label': 'positive', 'score': 0.9998492002487183}],
#  [{'label': 'neutral', 'score': 0.9379099011421204}],
#  [{'label': 'positive', 'score': 0.9997864365577698}],
#  [{'label': 'positive', 'score': 0.9998051524162292}],
#  [{'label': 'neutral', 'score': 0.9410901069641113}],
#  [{'label': 'positive', 'score': 0.9838522672653198}],
#  [{'label': 'positive', 'score': 0.9919965863227844}],
#  [{'label': 'positive', 'score': 0.9998605251312256}],
#  [{'label': 'positive', 'score': 0.9995235204696655}],
#  [{'label': 'positive', 'score': 0.8508396148681641}],
#  [{'label': 'positive', 'score': 0.7487608790397644}],
#  [{'label': 'positive', 'score': 0.9079208970069885}],
#  [{'label': 'neutral', 'score': 0.9911410808563232}],
#  [{'label': 'positive', 'score': 0.9734936952590942}],
#  [{'label': 'neutral', 'score': 0.979516863822937}],
#  [{'label': 'positive', 'score': 0.9697525501251221}],
#  [{'label': 'neutral', 'score': 0.9981398582458496}],
#  [{'label': 'positive', 'score': 0.9998829364776611}],
#  [{'label': 'neutral', 'score': 0.9951046705245972}],
#  [{'label': 'neutral', 'score': 0.9715145230293274}],
#  [{'label': 'neutral', 'score': 0.9068787693977356}],
#  [{'label': 'neutral', 'score': 0.9939569234848022}],
#  [{'label': 'positive', 'score': 0.9997126460075378}],
#  [{'label': 'neutral', 'score': 0.9140844941139221}],
#  [{'label': 'neutral', 'score': 0.9998169541358948}],
#  [{'label': 'positive', 'score': 0.9665923118591309}],
#  [{'label': 'neutral', 'score': 0.9855905771255493}],
#  [{'label': 'positive', 'score': 0.9998735189437866}],
#  [{'label': 'positive', 'score': 0.9897809028625488}],
#  [{'label': 'positive', 'score': 0.9995940327644348}],
#  [{'label': 'positive', 'score': 0.9914137125015259}],
#  [{'label': 'positive', 'score': 0.9998672008514404}],
#  [{'label': 'positive', 'score': 0.9998817443847656}],
#  [{'label': 'positive', 'score': 0.9998414516448975}],
#  [{'label': 'positive', 'score': 0.9998599290847778}],
#  [{'label': 'positive', 'score': 0.9998233914375305}],
#  [{'label': 'positive', 'score': 0.9930998086929321}],
#  [{'label': 'positive', 'score': 0.9998239874839783}],
#  [{'label': 'positive', 'score': 0.9998801946640015}],
#  [{'label': 'neutral', 'score': 0.706057071685791}],
#  [{'label': 'positive', 'score': 0.9998568296432495}],
#  [{'label': 'positive', 'score': 0.9993820190429688}],
#  [{'label': 'positive', 'score': 0.999861478805542}],
#  [{'label': 'neutral', 'score': 0.999874472618103}],
#  [{'label': 'positive', 'score': 0.999870777130127}],
#  [{'label': 'neutral', 'score': 0.9998934268951416}],
#  [{'label': 'neutral', 'score': 0.9187681674957275}],
#  [{'label': 'neutral', 'score': 0.9119959473609924}],
#  [{'label': 'neutral', 'score': 0.9997796416282654}],
#  [{'label': 'positive', 'score': 0.9998906850814819}],
#  [{'label': 'positive', 'score': 0.9996552467346191}],
#  [{'label': 'positive', 'score': 0.9998751878738403}],
#  [{'label': 'neutral', 'score': 0.9998961687088013}],
#  [{'label': 'positive', 'score': 0.9994232654571533}],
#  [{'label': 'positive', 'score': 0.8079861998558044}],
#  [{'label': 'neutral', 'score': 0.5323337912559509}],
#  [{'label': 'positive', 'score': 0.9998749494552612}],
#  [{'label': 'positive', 'score': 0.9998292922973633}],
#  [{'label': 'positive', 'score': 0.9998470544815063}],
#  [{'label': 'negative', 'score': 0.512840747833252}],
#  [{'label': 'positive', 'score': 0.9995017051696777}],
#  [{'label': 'positive', 'score': 0.7345219850540161}],
#  [{'label': 'negative', 'score': 0.8032469749450684}],
#  [{'label': 'positive', 'score': 0.9996949434280396}],
#  [{'label': 'positive', 'score': 0.9998422861099243}],
#  [{'label': 'positive', 'score': 0.9997981190681458}],
#  [{'label': 'positive', 'score': 0.9997397065162659}],
#  [{'label': 'neutral', 'score': 0.9151424169540405}],
#  [{'label': 'neutral', 'score': 0.9986472725868225}],
#  [{'label': 'positive', 'score': 0.9998520612716675}],
#  [{'label': 'positive', 'score': 0.9997690320014954}],
#  [{'label': 'positive', 'score': 0.9998745918273926}],
#  [{'label': 'positive', 'score': 0.9998911619186401}],
#  [{'label': 'positive', 'score': 0.9998181462287903}],
#  [{'label': 'positive', 'score': 0.999860405921936}],
#  [{'label': 'positive', 'score': 0.9998650550842285}],
#  [{'label': 'positive', 'score': 0.9996179342269897}],
#  [{'label': 'positive', 'score': 0.999868631362915}],
#  [{'label': 'positive', 'score': 0.9982732534408569}],
#  [{'label': 'positive', 'score': 0.9998733997344971}],
#  [{'label': 'positive', 'score': 0.9983046054840088}],
#  [{'label': 'positive', 'score': 0.9998717308044434}],
#  [{'label': 'positive', 'score': 0.9995891451835632}],
#  [{'label': 'positive', 'score': 0.9998656511306763}],
#  [{'label': 'positive', 'score': 0.9996778964996338}],
#  [{'label': 'positive', 'score': 0.9997969269752502}],
#  [{'label': 'neutral', 'score': 0.9975128173828125}],
#  [{'label': 'positive', 'score': 0.9998458623886108}],
#  [{'label': 'positive', 'score': 0.9998328685760498}],
#  [{'label': 'neutral', 'score': 0.9998230338096619}],
#  [{'label': 'neutral', 'score': 0.9998470544815063}],
#  [{'label': 'positive', 'score': 0.9932670593261719}],
#  [{'label': 'positive', 'score': 0.9997212290763855}],
#  [{'label': 'positive', 'score': 0.9994809031486511}],
#  [{'label': 'positive', 'score': 0.9998608827590942}],
#  [{'label': 'neutral', 'score': 0.9992672801017761}],
#  [{'label': 'negative', 'score': 0.9985737800598145}],
#  [{'label': 'neutral', 'score': 0.9988573789596558}],
#  [{'label': 'neutral', 'score': 0.9997580647468567}],
#  [{'label': 'positive', 'score': 0.9973387122154236}],
#  [{'label': 'positive', 'score': 0.9998794794082642}],
#  [{'label': 'positive', 'score': 0.999302864074707}],
#  [{'label': 'positive', 'score': 0.9998511075973511}],
#  [{'label': 'positive', 'score': 0.9998362064361572}],
#  [{'label': 'positive', 'score': 0.999872088432312}],
#  [{'label': 'positive', 'score': 0.9993669390678406}],
#  [{'label': 'positive', 'score': 0.9998792409896851}],
#  [{'label': 'negative', 'score': 0.9995476603507996}],
#  [{'label': 'positive', 'score': 0.9741516709327698}],
#  [{'label': 'positive', 'score': 0.9997043013572693}],
#  [{'label': 'positive', 'score': 0.9998810291290283}],
#  [{'label': 'positive', 'score': 0.9997103810310364}],
#  [{'label': 'positive', 'score': 0.9998598098754883}],
#  [{'label': 'positive', 'score': 0.9985016584396362}],
#  [{'label': 'positive', 'score': 0.9997755885124207}],
#  [{'label': 'positive', 'score': 0.9998854398727417}],
#  [{'label': 'positive', 'score': 0.9997701048851013}],
#  [{'label': 'positive', 'score': 0.998802661895752}],
#  [{'label': 'positive', 'score': 0.9998819828033447}],
#  [{'label': 'positive', 'score': 0.9997397065162659}],
#  [{'label': 'positive', 'score': 0.9998843669891357}],
#  [{'label': 'positive', 'score': 0.9997708201408386}],
#  [{'label': 'positive', 'score': 0.999868631362915}],
#  [{'label': 'positive', 'score': 0.9996063113212585}],
#  [{'label': 'positive', 'score': 0.9732064008712769}],
#  [{'label': 'positive', 'score': 0.9998425245285034}],
#  [{'label': 'positive', 'score': 0.9998594522476196}],
#  [{'label': 'positive', 'score': 0.999800980091095}],
#  [{'label': 'positive', 'score': 0.9895240664482117}],
#  [{'label': 'positive', 'score': 0.9998834133148193}],
#  [{'label': 'positive', 'score': 0.9996812343597412}],
#  [{'label': 'positive', 'score': 0.9997758269309998}],
#  [{'label': 'positive', 'score': 0.7958629727363586}],
#  [{'label': 'positive', 'score': 0.9998513460159302}],
#  [{'label': 'positive', 'score': 0.9994729161262512}],
#  [{'label': 'positive', 'score': 0.9996520280838013}],
#  [{'label': 'positive', 'score': 0.995342493057251}],
#  [{'label': 'positive', 'score': 0.9990161657333374}],
#  [{'label': 'positive', 'score': 0.9997426867485046}],
#  [{'label': 'positive', 'score': 0.9998595714569092}],
#  [{'label': 'positive', 'score': 0.9928938746452332}],
#  [{'label': 'positive', 'score': 0.9998599290847778}],
#  [{'label': 'positive', 'score': 0.9998773336410522}],
#  [{'label': 'positive', 'score': 0.9994729161262512}],
#  [{'label': 'negative', 'score': 0.961736798286438}],
#  [{'label': 'positive', 'score': 0.999884843826294}],
#  [{'label': 'positive', 'score': 0.9998206496238708}],
#  [{'label': 'positive', 'score': 0.9995003938674927}],
#  [{'label': 'positive', 'score': 0.9997406601905823}],
#  [{'label': 'positive', 'score': 0.9998711347579956}],
#  [{'label': 'positive', 'score': 0.9998793601989746}],
#  [{'label': 'neutral', 'score': 0.9648428559303284}],
#  [{'label': 'neutral', 'score': 0.999804675579071}],
#  [{'label': 'neutral', 'score': 0.9992846846580505}],
#  [{'label': 'neutral', 'score': 0.9998502731323242}],
#  [{'label': 'neutral', 'score': 0.9991781115531921}],
#  [{'label': 'neutral', 'score': 0.9984149932861328}],
#  [{'label': 'neutral', 'score': 0.9867308139801025}],
#  [{'label': 'positive', 'score': 0.9998573064804077}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9918398857116699}],
#  [{'label': 'neutral', 'score': 0.9997580647468567}],
#  [{'label': 'neutral', 'score': 0.9995607733726501}],
#  [{'label': 'neutral', 'score': 0.9976174235343933}],
#  [{'label': 'neutral', 'score': 0.9976194500923157}],
#  [{'label': 'positive', 'score': 0.9994691014289856}],
#  [{'label': 'neutral', 'score': 0.8682422041893005}],
#  [{'label': 'neutral', 'score': 0.9993576407432556}],
#  [{'label': 'neutral', 'score': 0.999736487865448}],
#  [{'label': 'positive', 'score': 0.9996340274810791}],
#  [{'label': 'neutral', 'score': 0.999855637550354}],
#  [{'label': 'neutral', 'score': 0.9998089671134949}],
#  [{'label': 'positive', 'score': 0.9997372031211853}],
#  [{'label': 'neutral', 'score': 0.9997621178627014}],
#  [{'label': 'neutral', 'score': 0.9998874664306641}],
#  [{'label': 'positive', 'score': 0.9998113512992859}],
#  [{'label': 'neutral', 'score': 0.9980042576789856}],
#  [{'label': 'neutral', 'score': 0.999685525894165}],
#  [{'label': 'neutral', 'score': 0.9988910555839539}],
#  [{'label': 'neutral', 'score': 0.9997939467430115}],
#  [{'label': 'neutral', 'score': 0.998029887676239}],
#  [{'label': 'negative', 'score': 0.9995133876800537}],
#  [{'label': 'neutral', 'score': 0.9998458623886108}],
#  [{'label': 'neutral', 'score': 0.9989873766899109}],
#  [{'label': 'neutral', 'score': 0.9996994733810425}],
#  [{'label': 'neutral', 'score': 0.9998230338096619}],
#  [{'label': 'neutral', 'score': 0.9998513460159302}],
#  [{'label': 'neutral', 'score': 0.998863935470581}],
#  [{'label': 'neutral', 'score': 0.9912928938865662}],
#  [{'label': 'positive', 'score': 0.9993360638618469}],
#  [{'label': 'positive', 'score': 0.9994608759880066}],
#  [{'label': 'positive', 'score': 0.9997294545173645}],
#  [{'label': 'neutral', 'score': 0.888538658618927}],
#  [{'label': 'negative', 'score': 0.9158675670623779}],
#  [{'label': 'positive', 'score': 0.9998608827590942}],
#  [{'label': 'neutral', 'score': 0.9703149795532227}],
#  [{'label': 'neutral', 'score': 0.5908563733100891}],
#  [{'label': 'neutral', 'score': 0.9977203011512756}],
#  [{'label': 'neutral', 'score': 0.9998254179954529}],
#  [{'label': 'neutral', 'score': 0.9926164746284485}],
#  [{'label': 'neutral', 'score': 0.9998112320899963}],
#  [{'label': 'neutral', 'score': 0.9998376369476318}],
#  [{'label': 'neutral', 'score': 0.999776303768158}],
#  [{'label': 'neutral', 'score': 0.9996654987335205}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9978019595146179}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9961251616477966}],
#  [{'label': 'neutral', 'score': 0.7348923087120056}],
#  [{'label': 'neutral', 'score': 0.999625563621521}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9991865754127502}],
#  [{'label': 'positive', 'score': 0.9998847246170044}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994899034500122}],
#  [{'label': 'neutral', 'score': 0.9997630715370178}],
#  [{'label': 'neutral', 'score': 0.9991982579231262}],
#  [{'label': 'positive', 'score': 0.9998890161514282}],
#  [{'label': 'neutral', 'score': 0.9995846152305603}],
#  [{'label': 'neutral', 'score': 0.9944196343421936}],
#  [{'label': 'neutral', 'score': 0.9993102550506592}],
#  [{'label': 'neutral', 'score': 0.9998428821563721}],
#  [{'label': 'neutral', 'score': 0.9998601675033569}],
#  [{'label': 'positive', 'score': 0.9998767375946045}],
#  [{'label': 'neutral', 'score': 0.9991094470024109}],
#  [{'label': 'neutral', 'score': 0.9992066025733948}],
#  [{'label': 'neutral', 'score': 0.9998655319213867}],
#  [{'label': 'neutral', 'score': 0.9988883137702942}],
#  [{'label': 'neutral', 'score': 0.999494194984436}],
#  [{'label': 'positive', 'score': 0.999884843826294}],
#  [{'label': 'positive', 'score': 0.9998636245727539}],
#  [{'label': 'neutral', 'score': 0.9998775720596313}],
#  [{'label': 'positive', 'score': 0.999882698059082}],
#  [{'label': 'positive', 'score': 0.9998830556869507}],
#  [{'label': 'neutral', 'score': 0.999849796295166}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.999797523021698}],
#  [{'label': 'neutral', 'score': 0.9997804760932922}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9998062252998352}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'positive', 'score': 0.9998812675476074}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9998061060905457}],
#  [{'label': 'positive', 'score': 0.999880313873291}],
#  [{'label': 'neutral', 'score': 0.9998431205749512}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.99979168176651}],
#  [{'label': 'positive', 'score': 0.9998617172241211}],
#  [{'label': 'neutral', 'score': 0.9998257756233215}],
#  [{'label': 'neutral', 'score': 0.9984437823295593}],
#  [{'label': 'neutral', 'score': 0.9998353719711304}],
#  [{'label': 'neutral', 'score': 0.9998517036437988}],
#  [{'label': 'neutral', 'score': 0.9998806715011597}],
#  [{'label': 'neutral', 'score': 0.9995129108428955}],
#  [{'label': 'neutral', 'score': 0.9998371601104736}],
#  [{'label': 'neutral', 'score': 0.9990584254264832}],
#  [{'label': 'neutral', 'score': 0.9997122883796692}],
#  [{'label': 'neutral', 'score': 0.9980071187019348}],
#  [{'label': 'neutral', 'score': 0.9997087121009827}],
#  [{'label': 'neutral', 'score': 0.9998559951782227}],
#  [{'label': 'neutral', 'score': 0.9995129108428955}],
#  [{'label': 'positive', 'score': 0.9296666383743286}],
#  [{'label': 'positive', 'score': 0.9998741149902344}],
#  [{'label': 'positive', 'score': 0.999886155128479}],
#  [{'label': 'positive', 'score': 0.9998816251754761}],
#  [{'label': 'positive', 'score': 0.964936375617981}],
#  [{'label': 'positive', 'score': 0.9995942711830139}],
#  [{'label': 'positive', 'score': 0.9978370070457458}],
#  [{'label': 'positive', 'score': 0.8893100023269653}],
#  [{'label': 'neutral', 'score': 0.6960657238960266}],
#  [{'label': 'neutral', 'score': 0.7313637733459473}],
#  [{'label': 'negative', 'score': 0.9994059801101685}],
#  [{'label': 'neutral', 'score': 0.6103299260139465}],
#  [{'label': 'negative', 'score': 0.4136831760406494}],
#  [{'label': 'positive', 'score': 0.9983494281768799}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'neutral', 'score': 0.9804975986480713}],
#  [{'label': 'positive', 'score': 0.9955154061317444}],
#  [{'label': 'positive', 'score': 0.9996545314788818}],
#  [{'label': 'positive', 'score': 0.9998741149902344}],
#  [{'label': 'positive', 'score': 0.9983687996864319}],
#  [{'label': 'positive', 'score': 0.8766674399375916}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'positive', 'score': 0.9998873472213745}],
#  [{'label': 'positive', 'score': 0.9998776912689209}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'positive', 'score': 0.9994742274284363}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'neutral', 'score': 0.9993661046028137}],
#  [{'label': 'positive', 'score': 0.5251951813697815}],
#  [{'label': 'neutral', 'score': 0.999372661113739}],
#  [{'label': 'neutral', 'score': 0.9998831748962402}],
#  [{'label': 'positive', 'score': 0.8326735496520996}],
#  [{'label': 'neutral', 'score': 0.7363810539245605}],
#  [{'label': 'positive', 'score': 0.884055495262146}],
#  [{'label': 'neutral', 'score': 0.9993661046028137}],
#  [{'label': 'neutral', 'score': 0.999372661113739}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'neutral', 'score': 0.999534010887146}],
#  [{'label': 'positive', 'score': 0.9998799562454224}],
#  [{'label': 'positive', 'score': 0.9998546838760376}],
#  [{'label': 'neutral', 'score': 0.9998371601104736}],
#  [{'label': 'neutral', 'score': 0.9998816251754761}],
#  [{'label': 'neutral', 'score': 0.9954562187194824}],
#  [{'label': 'neutral', 'score': 0.9889012575149536}],
#  [{'label': 'neutral', 'score': 0.9997208714485168}],
#  [{'label': 'positive', 'score': 0.9996113181114197}],
#  [{'label': 'neutral', 'score': 0.999869704246521}],
#  [{'label': 'positive', 'score': 0.9977983832359314}],
#  [{'label': 'positive', 'score': 0.9993079900741577}],
#  [{'label': 'neutral', 'score': 0.9968307614326477}],
#  [{'label': 'positive', 'score': 0.9888781905174255}],
#  [{'label': 'positive', 'score': 0.9996910095214844}],
#  [{'label': 'positive', 'score': 0.968643069267273}],
#  [{'label': 'positive', 'score': 0.9997838139533997}],
#  [{'label': 'positive', 'score': 0.9976931214332581}],
#  [{'label': 'positive', 'score': 0.9994475245475769}],
#  [{'label': 'positive', 'score': 0.9998188614845276}],
#  [{'label': 'negative', 'score': 0.9991413354873657}],
#  [{'label': 'negative', 'score': 0.6049391031265259}],
#  [{'label': 'neutral', 'score': 0.9997580647468567}],
#  [{'label': 'neutral', 'score': 0.9994702935218811}],
#  [{'label': 'positive', 'score': 0.973128616809845}],
#  [{'label': 'neutral', 'score': 0.9984177350997925}],
#  [{'label': 'neutral', 'score': 0.9881724715232849}],
#  [{'label': 'neutral', 'score': 0.9991434812545776}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.999737560749054}],
#  [{'label': 'neutral', 'score': 0.9996322393417358}],
#  [{'label': 'neutral', 'score': 0.9997000694274902}],
#  [{'label': 'neutral', 'score': 0.992199718952179}],
#  [{'label': 'neutral', 'score': 0.9992032647132874}],
#  [{'label': 'neutral', 'score': 0.9886414408683777}],
#  [{'label': 'neutral', 'score': 0.9979828596115112}],
#  [{'label': 'neutral', 'score': 0.997538685798645}],
#  [{'label': 'neutral', 'score': 0.999754011631012}],
#  [{'label': 'neutral', 'score': 0.9996322393417358}],
#  [{'label': 'positive', 'score': 0.8269946575164795}],
#  [{'label': 'positive', 'score': 0.9674521088600159}],
#  [{'label': 'negative', 'score': 0.999739944934845}],
#  [{'label': 'neutral', 'score': 0.9989370703697205}],
#  [{'label': 'neutral', 'score': 0.9949501752853394}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9325417280197144}],
#  [{'label': 'positive', 'score': 0.9930764436721802}],
#  [{'label': 'neutral', 'score': 0.997078537940979}],
#  [{'label': 'neutral', 'score': 0.9951626062393188}],
#  [{'label': 'positive', 'score': 0.9251262545585632}],
#  [{'label': 'negative', 'score': 0.9997336268424988}],
#  [{'label': 'neutral', 'score': 0.979120135307312}],
#  [{'label': 'positive', 'score': 0.6693494915962219}],
#  [{'label': 'neutral', 'score': 0.9998691082000732}],
#  [{'label': 'neutral', 'score': 0.9942458271980286}],
#  [{'label': 'neutral', 'score': 0.9987691044807434}],
#  [{'label': 'positive', 'score': 0.8563787937164307}],
#  [{'label': 'neutral', 'score': 0.9950172305107117}],
#  [{'label': 'positive', 'score': 0.9997742772102356}],
#  [{'label': 'neutral', 'score': 0.9994818568229675}],
#  [{'label': 'neutral', 'score': 0.9990286827087402}],
#  [{'label': 'positive', 'score': 0.9979900121688843}],
#  [{'label': 'neutral', 'score': 0.9936389327049255}],
#  [{'label': 'neutral', 'score': 0.9357439875602722}],
#  [{'label': 'neutral', 'score': 0.9728376865386963}],
#  [{'label': 'neutral', 'score': 0.9987837672233582}],
#  [{'label': 'neutral', 'score': 0.8989961743354797}],
#  [{'label': 'neutral', 'score': 0.9985600113868713}],
#  [{'label': 'neutral', 'score': 0.9760825634002686}],
#  [{'label': 'neutral', 'score': 0.9998863935470581}],
#  [{'label': 'neutral', 'score': 0.9529178142547607}],
#  [{'label': 'neutral', 'score': 0.8364940285682678}],
#  [{'label': 'positive', 'score': 0.6141812801361084}],
#  [{'label': 'neutral', 'score': 0.999356210231781}],
#  [{'label': 'neutral', 'score': 0.9997320771217346}],
#  [{'label': 'positive', 'score': 0.6554802060127258}],
#  [{'label': 'neutral', 'score': 0.9985600113868713}],
#  [{'label': 'neutral', 'score': 0.9985600113868713}],
#  [{'label': 'neutral', 'score': 0.9921971559524536}],
#  [{'label': 'neutral', 'score': 0.9996697902679443}],
#  [{'label': 'neutral', 'score': 0.9991726279258728}],
#  [{'label': 'neutral', 'score': 0.9936673045158386}],
#  [{'label': 'neutral', 'score': 0.9997183680534363}],
#  [{'label': 'neutral', 'score': 0.9947319030761719}],
#  [{'label': 'neutral', 'score': 0.9995742440223694}],
#  [{'label': 'neutral', 'score': 0.9973435997962952}],
#  [{'label': 'neutral', 'score': 0.9963514804840088}],
#  [{'label': 'neutral', 'score': 0.9998288154602051}],
#  [{'label': 'neutral', 'score': 0.9991726279258728}],
#  [{'label': 'neutral', 'score': 0.9996925592422485}],
#  [{'label': 'neutral', 'score': 0.9899358153343201}],
#  [{'label': 'neutral', 'score': 0.6267953515052795}],
#  [{'label': 'neutral', 'score': 0.6145476698875427}],
#  [{'label': 'neutral', 'score': 0.9997010827064514}],
#  [{'label': 'neutral', 'score': 0.999487042427063}],
#  [{'label': 'neutral', 'score': 0.9991726279258728}],
#  [{'label': 'neutral', 'score': 0.9996925592422485}],
#  [{'label': 'negative', 'score': 0.999836802482605}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9271355867385864}],
#  [{'label': 'neutral', 'score': 0.9998437166213989}],
#  [{'label': 'neutral', 'score': 0.9237077832221985}],
#  [{'label': 'neutral', 'score': 0.9888485670089722}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9996449947357178}],
#  [{'label': 'negative', 'score': 0.9995905756950378}],
#  [{'label': 'neutral', 'score': 0.5780142545700073}],
#  [{'label': 'neutral', 'score': 0.9994195699691772}],
#  [{'label': 'neutral', 'score': 0.9907763600349426}],
#  [{'label': 'neutral', 'score': 0.9917110204696655}],
#  [{'label': 'neutral', 'score': 0.8698731660842896}],
#  [{'label': 'neutral', 'score': 0.9979585409164429}],
#  [{'label': 'neutral', 'score': 0.9996925592422485}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.9996449947357178}],
#  [{'label': 'negative', 'score': 0.9996682405471802}],
#  [{'label': 'neutral', 'score': 0.9974833130836487}],
#  [{'label': 'neutral', 'score': 0.9904781579971313}],
#  [{'label': 'neutral', 'score': 0.9998044371604919}],
#  [{'label': 'neutral', 'score': 0.9996503591537476}],
#  [{'label': 'neutral', 'score': 0.999737560749054}],
#  [{'label': 'neutral', 'score': 0.9998756647109985}],
#  [{'label': 'neutral', 'score': 0.9909658432006836}],
#  [{'label': 'neutral', 'score': 0.9847744107246399}],
#  [{'label': 'neutral', 'score': 0.9993467926979065}],
#  [{'label': 'neutral', 'score': 0.9998502731323242}],
#  [{'label': 'neutral', 'score': 0.999461829662323}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9995792508125305}],
#  [{'label': 'neutral', 'score': 0.9991958737373352}],
#  [{'label': 'neutral', 'score': 0.9815465807914734}],
#  [{'label': 'neutral', 'score': 0.99153733253479}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.999672532081604}],
#  [{'label': 'neutral', 'score': 0.9997064471244812}],
#  [{'label': 'neutral', 'score': 0.9937310218811035}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.999737560749054}],
#  [{'label': 'negative', 'score': 0.9993023872375488}],
#  [{'label': 'neutral', 'score': 0.9925577640533447}],
#  [{'label': 'neutral', 'score': 0.9826862812042236}],
#  [{'label': 'neutral', 'score': 0.9985690116882324}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9992165565490723}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.9918233752250671}],
#  [{'label': 'neutral', 'score': 0.999755322933197}],
#  [{'label': 'neutral', 'score': 0.9996819496154785}],
#  [{'label': 'neutral', 'score': 0.999737560749054}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.9876478910446167}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.9529959559440613}],
#  [{'label': 'neutral', 'score': 0.999737560749054}],
#  [{'label': 'neutral', 'score': 0.9997175335884094}],
#  [{'label': 'neutral', 'score': 0.9996708631515503}],
#  [{'label': 'neutral', 'score': 0.9998206496238708}],
#  [{'label': 'neutral', 'score': 0.9995328187942505}],
#  [{'label': 'neutral', 'score': 0.9970822930335999}],
#  [{'label': 'neutral', 'score': 0.9997095465660095}],
#  [{'label': 'neutral', 'score': 0.9994181394577026}],
#  [{'label': 'neutral', 'score': 0.9947808384895325}],
#  [{'label': 'positive', 'score': 0.9998698234558105}],
#  [{'label': 'positive', 'score': 0.9997738003730774}],
#  [{'label': 'positive', 'score': 0.999882698059082}],
#  [{'label': 'positive', 'score': 0.9669592976570129}],
#  [{'label': 'positive', 'score': 0.9998795986175537}],
#  [{'label': 'neutral', 'score': 0.9898759722709656}],
#  [{'label': 'neutral', 'score': 0.9998937845230103}],
#  [{'label': 'neutral', 'score': 0.9611579775810242}],
#  [{'label': 'neutral', 'score': 0.9997877478599548}],
#  [{'label': 'neutral', 'score': 0.9997914433479309}],
#  [{'label': 'positive', 'score': 0.9966825842857361}],
#  [{'label': 'positive', 'score': 0.984703779220581}],
#  [{'label': 'neutral', 'score': 0.9998811483383179}],
#  [{'label': 'positive', 'score': 0.9998877048492432}],
#  [{'label': 'neutral', 'score': 0.9525317549705505}],
#  [{'label': 'neutral', 'score': 0.9998886585235596}],
#  [{'label': 'neutral', 'score': 0.9078183174133301}],
#  [{'label': 'neutral', 'score': 0.9998525381088257}],
#  [{'label': 'neutral', 'score': 0.9972219467163086}],
#  [{'label': 'neutral', 'score': 0.9998134970664978}],
#  [{'label': 'neutral', 'score': 0.9990705847740173}],
#  [{'label': 'positive', 'score': 0.9998610019683838}],
#  [{'label': 'neutral', 'score': 0.9998124241828918}],
#  [{'label': 'neutral', 'score': 0.9998664855957031}],
#  [{'label': 'neutral', 'score': 0.9998354911804199}],
#  [{'label': 'positive', 'score': 0.99974125623703}],
#  [{'label': 'neutral', 'score': 0.9996567964553833}],
#  [{'label': 'positive', 'score': 0.9998792409896851}],
#  [{'label': 'positive', 'score': 0.9998701810836792}],
#  [{'label': 'neutral', 'score': 0.9998224377632141}],
#  [{'label': 'neutral', 'score': 0.9998846054077148}],
#  [{'label': 'neutral', 'score': 0.9998194575309753}],
#  [{'label': 'positive', 'score': 0.9998675584793091}],
#  [{'label': 'neutral', 'score': 0.9985771179199219}],
#  [{'label': 'positive', 'score': 0.9984410405158997}],
#  [{'label': 'neutral', 'score': 0.9998694658279419}],
#  [{'label': 'positive', 'score': 0.9998489618301392}],
#  [{'label': 'neutral', 'score': 0.9592863321304321}],
#  [{'label': 'positive', 'score': 0.9599437713623047}],
#  [{'label': 'positive', 'score': 0.6329782605171204}],
#  [{'label': 'neutral', 'score': 0.9995556473731995}],
#  [{'label': 'neutral', 'score': 0.9996639490127563}],
#  [{'label': 'neutral', 'score': 0.9997884631156921}],
#  [{'label': 'neutral', 'score': 0.9991196990013123}],
#  [{'label': 'neutral', 'score': 0.9998144507408142}],
#  [{'label': 'positive', 'score': 0.9886300563812256}],
#  [{'label': 'positive', 'score': 0.9998427629470825}],
#  [{'label': 'neutral', 'score': 0.9997314810752869}],
#  [{'label': 'positive', 'score': 0.9946625828742981}],
#  [{'label': 'neutral', 'score': 0.9997623562812805}],
#  [{'label': 'neutral', 'score': 0.9998674392700195}],
#  [{'label': 'neutral', 'score': 0.9794495105743408}],
#  [{'label': 'neutral', 'score': 0.9996017813682556}],
#  [{'label': 'neutral', 'score': 0.9994698166847229}],
#  [{'label': 'neutral', 'score': 0.9998979568481445}],
#  [{'label': 'neutral', 'score': 0.9941984415054321}],
#  [{'label': 'positive', 'score': 0.999882698059082}],
#  [{'label': 'neutral', 'score': 0.999803364276886}],
#  [{'label': 'positive', 'score': 0.9998347759246826}],
#  [{'label': 'neutral', 'score': 0.9977988600730896}],
#  [{'label': 'neutral', 'score': 0.9998846054077148}],
#  [{'label': 'neutral', 'score': 0.9990102052688599}],
#  [{'label': 'neutral', 'score': 0.9997877478599548}],
#  [{'label': 'positive', 'score': 0.999619722366333}],
#  [{'label': 'neutral', 'score': 0.9995959401130676}],
#  [{'label': 'neutral', 'score': 0.9987183809280396}],
#  [{'label': 'neutral', 'score': 0.9999024868011475}],
#  [{'label': 'positive', 'score': 0.9978221654891968}],
#  [{'label': 'neutral', 'score': 0.9998931884765625}],
#  [{'label': 'neutral', 'score': 0.9995959401130676}],
#  [{'label': 'neutral', 'score': 0.9918904304504395}],
#  [{'label': 'neutral', 'score': 0.9998561143875122}],
#  [{'label': 'positive', 'score': 0.9867308139801025}],
#  [{'label': 'neutral', 'score': 0.9998846054077148}],
#  [{'label': 'neutral', 'score': 0.9979549646377563}],
#  [{'label': 'neutral', 'score': 0.9998254179954529}],
#  [{'label': 'neutral', 'score': 0.9998891353607178}],
#  [{'label': 'neutral', 'score': 0.9992225170135498}],
#  [{'label': 'neutral', 'score': 0.9995959401130676}],
#  [{'label': 'neutral', 'score': 0.7905718684196472}],
#  [{'label': 'neutral', 'score': 0.9995463490486145}],
#  [{'label': 'positive', 'score': 0.9998736381530762}],
#  [{'label': 'positive', 'score': 0.9992910623550415}],
#  [{'label': 'positive', 'score': 0.99988853931427}],
#  [{'label': 'neutral', 'score': 0.8985375165939331}],
#  [{'label': 'positive', 'score': 0.9998737573623657}],
#  [{'label': 'negative', 'score': 0.720082700252533}],
#  [{'label': 'positive', 'score': 0.9998711347579956}],
#  [{'label': 'positive', 'score': 0.9998650550842285}],
#  [{'label': 'positive', 'score': 0.9998774528503418}],
#  [{'label': 'positive', 'score': 0.9998654127120972}],
#  [{'label': 'positive', 'score': 0.9997305274009705}],
#  [{'label': 'positive', 'score': 0.9998624324798584}],
#  [{'label': 'positive', 'score': 0.9998420476913452}],
#  [{'label': 'positive', 'score': 0.9998453855514526}],
#  [{'label': 'positive', 'score': 0.9998389482498169}],
#  [{'label': 'positive', 'score': 0.9998562335968018}],
#  [{'label': 'positive', 'score': 0.920346736907959}],
#  [{'label': 'negative', 'score': 0.9987579584121704}],
#  [{'label': 'positive', 'score': 0.9900923371315002}],
#  [{'label': 'positive', 'score': 0.9998792409896851}],
#  [{'label': 'positive', 'score': 0.9998842477798462}],
#  [{'label': 'positive', 'score': 0.9998782873153687}],
#  [{'label': 'positive', 'score': 0.9998843669891357}],
#  [{'label': 'positive', 'score': 0.9998862743377686}],
#  [{'label': 'positive', 'score': 0.99985671043396}],
#  [{'label': 'positive', 'score': 0.9998583793640137}],
#  [{'label': 'positive', 'score': 0.9993246793746948}],
#  [{'label': 'positive', 'score': 0.9998586177825928}],
#  [{'label': 'negative', 'score': 0.6886142492294312}],
#  [{'label': 'positive', 'score': 0.999809205532074}],
#  [{'label': 'positive', 'score': 0.9998583793640137}],
#  [{'label': 'positive', 'score': 0.9998664855957031}],
#  [{'label': 'positive', 'score': 0.979141891002655}],
#  [{'label': 'positive', 'score': 0.9998773336410522}],
#  [{'label': 'positive', 'score': 0.5939444899559021}],
#  [{'label': 'positive', 'score': 0.999874472618103}],
#  [{'label': 'positive', 'score': 0.9998437166213989}],
#  [{'label': 'positive', 'score': 0.9998821020126343}],
#  [{'label': 'positive', 'score': 0.7837756872177124}],
#  [{'label': 'positive', 'score': 0.8950420618057251}],
#  [{'label': 'positive', 'score': 0.9989373087882996}],
#  [{'label': 'positive', 'score': 0.9992163181304932}],
#  [{'label': 'negative', 'score': 0.9994664788246155}],
#  [{'label': 'positive', 'score': 0.9998421669006348}],
#  [{'label': 'positive', 'score': 0.9998780488967896}],
#  [{'label': 'positive', 'score': 0.9998780488967896}],
#  [{'label': 'positive', 'score': 0.9998513460159302}],
#  [{'label': 'positive', 'score': 0.9998701810836792}],
#  [{'label': 'positive', 'score': 0.9998650550842285}],
#  [{'label': 'positive', 'score': 0.9998599290847778}],
#  [{'label': 'positive', 'score': 0.999823272228241}],
#  [{'label': 'neutral', 'score': 0.8684255480766296}],
#  [{'label': 'positive', 'score': 0.979141891002655}],
#  [{'label': 'neutral', 'score': 0.9996668100357056}],
#  [{'label': 'positive', 'score': 0.9998515844345093}],
#  [{'label': 'positive', 'score': 0.999862790107727}],
#  [{'label': 'positive', 'score': 0.9998706579208374}],
#  [{'label': 'positive', 'score': 0.9970867037773132}],
#  [{'label': 'neutral', 'score': 0.6881163716316223}],
#  [{'label': 'positive', 'score': 0.999850869178772}],
#  [{'label': 'negative', 'score': 0.9996978044509888}],
#  [{'label': 'positive', 'score': 0.9998847246170044}],
#  [{'label': 'negative', 'score': 0.999818742275238}],
#  [{'label': 'positive', 'score': 0.9998568296432495}],
#  [{'label': 'negative', 'score': 0.9998108744621277}],
#  [{'label': 'positive', 'score': 0.9997645020484924}],
#  [{'label': 'positive', 'score': 0.9969667792320251}],
#  [{'label': 'positive', 'score': 0.9998420476913452}],
#  [{'label': 'positive', 'score': 0.9998650550842285}],
#  [{'label': 'positive', 'score': 0.9998714923858643}],
#  [{'label': 'positive', 'score': 0.9995784163475037}],
#  [{'label': 'positive', 'score': 0.9998112320899963}],
#  [{'label': 'positive', 'score': 0.9998601675033569}],
#  [{'label': 'negative', 'score': 0.9997832179069519}],
#  [{'label': 'positive', 'score': 0.9998490810394287}],
#  [{'label': 'positive', 'score': 0.9998453855514526}],
#  [{'label': 'positive', 'score': 0.9998561143875122}],
#  [{'label': 'positive', 'score': 0.9998002648353577}],
#  [{'label': 'positive', 'score': 0.9998453855514526}],
#  [{'label': 'positive', 'score': 0.9998699426651001}],
#  [{'label': 'positive', 'score': 0.9896243214607239}],
#  [{'label': 'positive', 'score': 0.9998743534088135}],
#  [{'label': 'positive', 'score': 0.9998313188552856}],
#  [{'label': 'positive', 'score': 0.9996542930603027}],
#  [{'label': 'positive', 'score': 0.9998631477355957}],
#  [{'label': 'positive', 'score': 0.999789297580719}],
#  [{'label': 'positive', 'score': 0.8923036456108093}],
#  [{'label': 'positive', 'score': 0.9998111128807068}],
#  [{'label': 'neutral', 'score': 0.530445396900177}],
#  [{'label': 'positive', 'score': 0.9991183876991272}],
#  [{'label': 'neutral', 'score': 0.8798113465309143}],
#  [{'label': 'positive', 'score': 0.9998432397842407}],
#  [{'label': 'positive', 'score': 0.9998427629470825}],
#  [{'label': 'positive', 'score': 0.9963647723197937}],
#  [{'label': 'positive', 'score': 0.999671220779419}],
#  [{'label': 'negative', 'score': 0.9980352520942688}],
#  [{'label': 'positive', 'score': 0.9926458597183228}],
#  [{'label': 'positive', 'score': 0.9884381890296936}],
#  [{'label': 'neutral', 'score': 0.9998615980148315}],
#  [{'label': 'negative', 'score': 0.932745635509491}],
#  [{'label': 'neutral', 'score': 0.9994801878929138}],
#  [{'label': 'neutral', 'score': 0.9998761415481567}],
#  [{'label': 'positive', 'score': 0.9998672008514404}],
#  [{'label': 'neutral', 'score': 0.9998615980148315}],
#  [{'label': 'neutral', 'score': 0.5214396715164185}],
#  [{'label': 'negative', 'score': 0.9997431635856628}],
#  [{'label': 'neutral', 'score': 0.9998849630355835}],
#  [{'label': 'neutral', 'score': 0.9952933192253113}],
#  [{'label': 'neutral', 'score': 0.9998615980148315}],
#  [{'label': 'positive', 'score': 0.9976772665977478}],
#  [{'label': 'neutral', 'score': 0.9759082794189453}],
#  [{'label': 'positive', 'score': 0.8652080297470093}],
#  [{'label': 'negative', 'score': 0.9995799660682678}],
#  [{'label': 'neutral', 'score': 0.9972988963127136}],
#  [{'label': 'positive', 'score': 0.9997503161430359}],
#  [{'label': 'negative', 'score': 0.9996920824050903}],
#  [{'label': 'positive', 'score': 0.9954837560653687}],
#  [{'label': 'neutral', 'score': 0.9998331069946289}],
#  [{'label': 'neutral', 'score': 0.9996856451034546}],
#  [{'label': 'neutral', 'score': 0.9775105118751526}],
#  [{'label': 'positive', 'score': 0.9968462586402893}],
#  [{'label': 'neutral', 'score': 0.6244620084762573}],
#  [{'label': 'neutral', 'score': 0.9895750880241394}],
#  [{'label': 'neutral', 'score': 0.5991581678390503}],
#  [{'label': 'positive', 'score': 0.9998711347579956}],
#  [{'label': 'positive', 'score': 0.9957173466682434}],
#  [{'label': 'neutral', 'score': 0.5644140243530273}],
#  [{'label': 'positive', 'score': 0.7051337361335754}],
#  [{'label': 'neutral', 'score': 0.9998304843902588}],
#  [{'label': 'neutral', 'score': 0.9671661257743835}],
#  [{'label': 'positive', 'score': 0.999874472618103}],
#  [{'label': 'positive', 'score': 0.6489842534065247}],
#  [{'label': 'neutral', 'score': 0.9727814793586731}],
#  [{'label': 'positive', 'score': 0.7856763005256653}],
#  [{'label': 'neutral', 'score': 0.9996856451034546}],
#  [{'label': 'neutral', 'score': 0.9996856451034546}],
#  [{'label': 'neutral', 'score': 0.9997671246528625}],
#  [{'label': 'positive', 'score': 0.9974533915519714}],
#  [{'label': 'neutral', 'score': 0.9995033740997314}],
#  [{'label': 'positive', 'score': 0.8326161503791809}],
#  [{'label': 'neutral', 'score': 0.9995837807655334}],
#  [{'label': 'positive', 'score': 0.9911203980445862}],
#  [{'label': 'positive', 'score': 0.9998565912246704}],
#  [{'label': 'neutral', 'score': 0.9996770620346069}],
#  [{'label': 'positive', 'score': 0.9995367527008057}],
#  [{'label': 'positive', 'score': 0.9998867511749268}],
#  [{'label': 'positive', 'score': 0.9998844861984253}],
#  [{'label': 'positive', 'score': 0.999875545501709}],
#  [{'label': 'positive', 'score': 0.9715301394462585}],
#  [{'label': 'neutral', 'score': 0.9996856451034546}],
#  [{'label': 'positive', 'score': 0.9997950196266174}],
#  [{'label': 'positive', 'score': 0.8944209814071655}],
#  [{'label': 'positive', 'score': 0.999812662601471}],
#  [{'label': 'positive', 'score': 0.9998599290847778}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9981361627578735}],
#  [{'label': 'positive', 'score': 0.9003251194953918}],
#  [{'label': 'positive', 'score': 0.999721109867096}],
#  [{'label': 'positive', 'score': 0.9998642206192017}],
#  [{'label': 'positive', 'score': 0.9998644590377808}],
#  [{'label': 'positive', 'score': 0.946252167224884}],
#  [{'label': 'positive', 'score': 0.9998717308044434}],
#  [{'label': 'positive', 'score': 0.9998717308044434}],
#  [{'label': 'positive', 'score': 0.9998589754104614}],
#  [{'label': 'positive', 'score': 0.9964314699172974}],
#  [{'label': 'positive', 'score': 0.9997355341911316}],
#  [{'label': 'positive', 'score': 0.999580442905426}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.999904990196228}],
#  [{'label': 'neutral', 'score': 0.9978785514831543}],
#  [{'label': 'positive', 'score': 0.9932531714439392}],
#  [{'label': 'negative', 'score': 0.9927943348884583}],
#  [{'label': 'positive', 'score': 0.9996966123580933}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.8716853260993958}],
#  [{'label': 'neutral', 'score': 0.9998154044151306}],
#  [{'label': 'neutral', 'score': 0.9998154044151306}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'positive', 'score': 0.5441625118255615}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'positive', 'score': 0.996728777885437}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'neutral', 'score': 0.9990990161895752}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'positive', 'score': 0.9987824559211731}],
#  [{'label': 'neutral', 'score': 0.9995611310005188}],
#  [{'label': 'negative', 'score': 0.9960638880729675}],
#  [{'label': 'neutral', 'score': 0.9968593120574951}],
#  [{'label': 'positive', 'score': 0.9987824559211731}],
#  [{'label': 'neutral', 'score': 0.5155320763587952}],
#  [{'label': 'positive', 'score': 0.9997972846031189}],
#  [{'label': 'positive', 'score': 0.999653697013855}],
#  [{'label': 'neutral', 'score': 0.6046749949455261}],
#  [{'label': 'neutral', 'score': 0.9523260593414307}],
#  [{'label': 'positive', 'score': 0.8321239352226257}],
#  [{'label': 'positive', 'score': 0.9998737573623657}],
#  [{'label': 'positive', 'score': 0.9998757839202881}],
#  [{'label': 'positive', 'score': 0.9998031258583069}],
#  [{'label': 'positive', 'score': 0.9993438124656677}],
#  [{'label': 'positive', 'score': 0.9998143315315247}],
#  [{'label': 'positive', 'score': 0.9998745918273926}],
#  [{'label': 'positive', 'score': 0.999868631362915}],
#  [{'label': 'positive', 'score': 0.9998433589935303}],
#  [{'label': 'negative', 'score': 0.9906966686248779}],
#  [{'label': 'positive', 'score': 0.9902516603469849}],
#  [{'label': 'positive', 'score': 0.9998262524604797}],
#  [{'label': 'positive', 'score': 0.9995449185371399}],
#  [{'label': 'positive', 'score': 0.882723331451416}],
#  [{'label': 'positive', 'score': 0.9997788071632385}],
#  [{'label': 'positive', 'score': 0.9997168183326721}],
#  [{'label': 'positive', 'score': 0.5165665149688721}],
#  [{'label': 'neutral', 'score': 0.999750554561615}],
#  [{'label': 'negative', 'score': 0.9860347509384155}],
#  [{'label': 'positive', 'score': 0.9997405409812927}],
#  [{'label': 'positive', 'score': 0.9997860789299011}],
#  [{'label': 'positive', 'score': 0.9998389482498169}],
#  [{'label': 'positive', 'score': 0.999849796295166}],
#  [{'label': 'positive', 'score': 0.999839186668396}],
#  [{'label': 'positive', 'score': 0.9998195767402649}],
#  [{'label': 'positive', 'score': 0.9994679093360901}],
#  [{'label': 'positive', 'score': 0.9998717308044434}],
#  [{'label': 'neutral', 'score': 0.9914337396621704}],
#  [{'label': 'positive', 'score': 0.993507981300354}],
#  [{'label': 'positive', 'score': 0.981347918510437}],
#  [{'label': 'negative', 'score': 0.9994970560073853}],
#  [{'label': 'positive', 'score': 0.9937931299209595}],
#  [{'label': 'neutral', 'score': 0.9998878240585327}],
#  [{'label': 'negative', 'score': 0.9997701048851013}],
#  [{'label': 'positive', 'score': 0.9981880784034729}],
#  [{'label': 'positive', 'score': 0.9991232752799988}],
#  [{'label': 'negative', 'score': 0.9998013377189636}],
#  [{'label': 'positive', 'score': 0.99986732006073}],
#  [{'label': 'negative', 'score': 0.9998255372047424}],
#  [{'label': 'neutral', 'score': 0.9709886908531189}],
#  [{'label': 'negative', 'score': 0.9997261166572571}],
#  [{'label': 'neutral', 'score': 0.9998965263366699}],
#  [{'label': 'neutral', 'score': 0.9994778037071228}],
#  [{'label': 'positive', 'score': 0.7781438827514648}],
#  [{'label': 'neutral', 'score': 0.9839762449264526}],
#  [{'label': 'positive', 'score': 0.998167872428894}],
#  [{'label': 'neutral', 'score': 0.6078459024429321}],
#  [{'label': 'positive', 'score': 0.9998526573181152}],
#  [{'label': 'positive', 'score': 0.9998831748962402}],
#  [{'label': 'positive', 'score': 0.9978474378585815}],
#  [{'label': 'neutral', 'score': 0.9997977614402771}],
#  [{'label': 'positive', 'score': 0.999866247177124}],
#  [{'label': 'positive', 'score': 0.9998778104782104}],
#  [{'label': 'neutral', 'score': 0.99960857629776}],
#  [{'label': 'neutral', 'score': 0.9998965263366699}],
#  [{'label': 'positive', 'score': 0.9918797612190247}],
#  [{'label': 'neutral', 'score': 0.9998965263366699}],
#  [{'label': 'neutral', 'score': 0.9998965263366699}],
#  [{'label': 'neutral', 'score': 0.9929392337799072}],
#  [{'label': 'neutral', 'score': 0.999747097492218}],
#  [{'label': 'neutral', 'score': 0.9959698915481567}],
#  [{'label': 'neutral', 'score': 0.9992896318435669}],
#  [{'label': 'neutral', 'score': 0.8042430281639099}],
#  [{'label': 'neutral', 'score': 0.752489447593689}],
#  [{'label': 'positive', 'score': 0.9509285092353821}],
#  [{'label': 'neutral', 'score': 0.9975188970565796}],
#  [{'label': 'positive', 'score': 0.9992758631706238}],
#  [{'label': 'neutral', 'score': 0.9768205881118774}],
#  [{'label': 'negative', 'score': 0.542435884475708}],
#  [{'label': 'neutral', 'score': 0.7438689470291138}],
#  [{'label': 'positive', 'score': 0.9891617298126221}],
#  [{'label': 'neutral', 'score': 0.9893494844436646}],
#  [{'label': 'positive', 'score': 0.9998555183410645}],
#  [{'label': 'neutral', 'score': 0.9885878562927246}],
#  [{'label': 'positive', 'score': 0.9976779818534851}],
#  [{'label': 'neutral', 'score': 0.9998158812522888}],
#  [{'label': 'neutral', 'score': 0.5241727232933044}],
#  [{'label': 'neutral', 'score': 0.9887794256210327}],
#  [{'label': 'neutral', 'score': 0.9917728304862976}],
#  [{'label': 'neutral', 'score': 0.9844384789466858}],
#  [{'label': 'positive', 'score': 0.9933752417564392}],
#  [{'label': 'positive', 'score': 0.9678028225898743}],
#  [{'label': 'positive', 'score': 0.999846339225769}],
#  ...]

# %%
df['title'].head(20)
# Out:
# 0              2025년 TTA 시험인증 대상 특별상 삼성전자 갤럭시S25FE
# 1                          삼성전자 GDDR7 D램으로 대통령상 수상
# 2              삼성전자 삼성 아트 스토어 아트 바젤 마이애미 비치 컬렉션 공개
# 3              포토 TTA 시험인증 대상 특별상에 삼성전자 갤럭시 S25 FE
# 4                  삼성전자 베트남 국적 임원 첫 탄생 현지 진출 17년 만
# 5                    비즈톡 메모리 가격 상승에 웃을 수만은 없는 삼성전자
# 6            대통령상만 11번째 삼성전자 세계 최초 D램 기술로 AI 추론 선도
# 7          삼성전자 GDDR7 대통령표창 받아...AI 연산에 활용되며 날개 다나
# 8               삼성전자 HBM4 내부 품질 테스트 통과 본격 양산 준비 완료
# 9              11번가 삼성전자 로보락 등 올해의 브랜드 와 연말 감사제 실시
# 10               GDDR7 대통령상 수상 삼성전자 AI 메모리 리더십 공고화
# 11         서울데이터랩 삼성전자 SK 하이닉스 등 개장 직후 인기 검색 종목 20
# 12               삼성전자 아트 스토어에 아트 바젤 마이애미 비치 컬렉션 공개
# 13           코스피 개인 순매수 속 4000선 안팎 공방 삼성전자 1 대 오름세
# 14                   4분기 실적 서프라이즈 전망에 삼성전자 매수세 몰렸다
# 15                            4000피 회복한 코스피 삼성전자 2
# 16                 삼성전자 아트 바젤 마이애미 비치 컬렉션 4K로 선보인다
# 17    리포트 브리핑 삼성전자 HBM4 연내 승인 전망 목표가 160 000원 KB증권
# 18            삼성전자 삼성 아트 스토어에 아트 바젤 마이애미 비치 컬렉션 공개
# 19     와이씨 내년 삼성전자 SK하이닉스 수요 확대 사상 최대 매출 전망 모닝 리포트
# Name: title, dtype: object

# %%
df['title'].tail(4)
# Out:
# 16240             로봇기업 품은 삼성전자 대표가 직접 지휘봉 잡는다
# 16241           빅테크 새 격전지는 로봇 삼성전자도 휴머노이드 만든다
# 16242    삼성전자 AI RAN기술 시연 통신 AI 융합기술로 미래 준비한다
# 16243    삼성전자 레인보우로보틱스 최대주주 지위 확보 미래로봇 개발 가속화
# Name: title, dtype: object

# %%
df['ticker'] = '005930'

# %%
df
# Out:
#            date                                 title  ticker
# 0      20251203   2025년 TTA 시험인증 대상 특별상 삼성전자 갤럭시S25FE  005930
# 1      20251203               삼성전자 GDDR7 D램으로 대통령상 수상  005930
# 2      20251203   삼성전자 삼성 아트 스토어 아트 바젤 마이애미 비치 컬렉션 공개  005930
# 3      20251203   포토 TTA 시험인증 대상 특별상에 삼성전자 갤럭시 S25 FE  005930
# 4      20251203       삼성전자 베트남 국적 임원 첫 탄생 현지 진출 17년 만  005930
# ...         ...                                   ...     ...
# 16239  20250101        삼성전자 레인보우로보틱스 품었다 미래 로봇 개발 가속도  005930
# 16240  20250101           로봇기업 품은 삼성전자 대표가 직접 지휘봉 잡는다  005930
# 16241  20250101         빅테크 새 격전지는 로봇 삼성전자도 휴머노이드 만든다  005930
# 16242  20250101  삼성전자 AI RAN기술 시연 통신 AI 융합기술로 미래 준비한다  005930
# 16243  20250101  삼성전자 레인보우로보틱스 최대주주 지위 확보 미래로봇 개발 가속화  005930
#
# [16244 rows x 3 columns]

# %%
df2['ticker'] = '005930'
# Out:
# C:\Users\rkdtk\AppData\Local\Temp\ipykernel_33568\2809714094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['ticker'] = '005930'

# %%
df2.drop(columns='sentiment', inplace = True)
# Out:
# C:\Users\rkdtk\AppData\Local\Temp\ipykernel_33568\833820993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns='sentiment', inplace = True)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import pandas as pd
from tqdm import tqdm



# 1) FinBERT 모델 로드

MODEL = "snunlp/KR-FinBert-SC"

tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

nlp = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    return_all_scores=True
)



# 2) 감성 점수 추출 함수
#    Sentiment = P(positive) - P(negative)

def get_sentiment(text: str) -> float:
    if not isinstance(text, str):
        return 0.0
    
    scores = nlp(text)[0]   # [{'label': 'positive', 'score': ...}, ...]
    
    pos = [s['score'] for s in scores if s['label'] == 'positive'][0]
    neg = [s['score'] for s in scores if s['label'] == 'negative'][0]
    
    return pos - neg        # 최종 감성 점수


# ------------------------------------------------------
# 3) 뉴스 데이터 예시 구조
#    df 컬럼: date(YYYY-MM-DD), ticker, title
# ------------------------------------------------------
# df = pd.read_csv("news.csv")  # 예시
# df["date"] = pd.to_datetime(df["date"])


# ------------------------------------------------------
# 4) 감성 점수 계산
# ------------------------------------------------------
tqdm.pandas(desc="Calculating Sentiment")
df["sentiment"] = df["title"].progress_apply(get_sentiment)


# ------------------------------------------------------
# 5) 종목/일자별 1일 감성 만들기 (여러 뉴스 평균)
# ------------------------------------------------------
daily_sentiment = (
    df.groupby(["ticker", "date"])["sentiment"]
      .mean()
      .reset_index()
      .sort_values(["ticker", "date"])
)


# ------------------------------------------------------
# 6) 종목별 3일 롤링 평균 감성 팩터 생성 (핵심)
# ------------------------------------------------------
daily_sentiment["sentiment_3d"] = (
    daily_sentiment
    .groupby("ticker")["sentiment"]
    .rolling(window=3, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)
# Out:
# Device set to use cpu
# c:\Users\rkdtk\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py:111: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Calculating Sentiment: 100%|██████████| 16244/16244 [08:15<00:00, 32.81it/s]

# %%
daily_sentiment
# Out:
#      ticker      date  sentiment  sentiment_3d
# 0    005930  20250101   0.523322      0.523322
# 1    005930  20250102   0.393929      0.458625
# 2    005930  20250103   0.646831      0.521361
# 3    005930  20250104   0.124300      0.388354
# 4    005930  20250105   0.140927      0.304020
# ..      ...       ...        ...           ...
# 332  005930  20251129   0.499914      0.481177
# 333  005930  20251130   0.720633      0.507541
# 334  005930  20251201   0.366668      0.529072
# 335  005930  20251202   0.672841      0.586714
# 336  005930  20251203   0.668389      0.569299
#
# [337 rows x 4 columns]
